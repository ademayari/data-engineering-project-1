# %%
import pandas as pd
import os
from pandas_analysis import load_all_csv

data = load_all_csv()

# %%
data
# Out:
#                            flight_id flightnumber departure_date arrival_date  \
# 0       FR_CRL_AGP_2023-04-30_FR1916       FR1916     2023-04-30   2023-04-30
# 1       FR_CRL_CFU_2023-04-30_FR6251       FR6251     2023-04-30   2023-04-30
# 2       FR_CRL_BDS_2023-04-30_FR7737       FR7737     2023-04-30   2023-04-30
# 3       FR_CRL_NAP_2023-04-30_FR1302       FR1302     2023-04-30   2023-04-30
# 4       FR_CRL_ALC_2023-04-30_FR3534       FR3534     2023-04-30   2023-04-30
# ...                              ...          ...            ...          ...
# 134875  TB_ANR_TFS_2023-10-02_TB1821       TB1821     2023-10-02   2023-10-02
# 134876  TB_BRU_TFS_2023-10-03_TB1753       TB1753     2023-10-03   2023-10-03
# 134877  TB_LGG_TFS_2023-10-04_TB1791       TB1791     2023-10-04   2023-10-04
# 134878  TB_OST_TFS_2023-10-04_TB1811       TB1811     2023-10-04   2023-10-04
# 134879  TB_BRU_TFS_2023-10-04_TB1751       TB1751     2023-10-04   2023-10-04
#
# ...
